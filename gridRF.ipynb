# %%
import pandas as pd

dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {'criterion':['squared_error','poisson','friedman_mse','absolute_error'],'n_estimators':[50,100],'max_features':['sqrt','log2',1.0]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'poisson',
#                                        'friedman_mse', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2', 1.0],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
table = pd.DataFrame.from_dict(re)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.783101      0.064793         0.021948        0.010553
# 1        1.350955      0.048962         0.030120        0.012559
# 2        0.670442      0.034071         0.019776        0.013129
# 3        1.329552      0.038238         0.057610        0.007147
# 4        0.964446      0.013393         0.040804        0.013991
# 5        1.978992      0.050678         0.034659        0.013803
# 6        0.763837      0.009914         0.013909        0.000375
# 7        1.473116      0.011316         0.050666        0.013819
# 8        0.774013      0.021530         0.013763        0.000399
# 9        1.481144      0.016125         0.045111        0.011458
# 10       1.084790      0.035230         0.033805        0.015441
# 11       2.180748      0.031989         0.038021        0.019146
# 12       0.669583      0.017208         0.028103        0.013065
# 13       1.342455      0.032265         0.037424        0.017008
# 14       0.666460      0.040176         0.039526        0.012477
# 15       1.362486      0.020824         0.051628        0.013959
# 16       1.074655      0.024685         0.019987        0.013070
# 17       2.205342      0.168058         0.046817        0.020737
# 18       1.852646      0.016740         0.025048        0.014999
# 19       3.691848      0.052452         0.037010        0.014816
# 20       1.909858      0.036920         0.020397        0.013371
# 21       3.695673      0.074064         0.035816        0.015715
# 22       3.189116      0.038193         0.026849        0.015793
# 23       6.132516      0.458152         0.049579        0.008887
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4    squared_error                1.0                 50
# 5    squared_error                1.0                100
# 6          poisson               sqrt                 50
# 7          poisson               sqrt                100
# 8          poisson               log2                 50
# 9          poisson               log2                100
# 10         poisson                1.0                 50
# 11         poisson                1.0                100
# 12    friedman_mse               sqrt                 50
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 50
# 15    friedman_mse               log2                100
# 16    friedman_mse                1.0                 50
# 17    friedman_mse                1.0                100
# 18  absolute_error               sqrt                 50
# 19  absolute_error               sqrt                100
# 20  absolute_error               log2                 50
# 21  absolute_error               log2                100
# 22  absolute_error                1.0                 50
# 23  absolute_error                1.0                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.861097
# 1   {'criterion': 'squared_error', 'max_features':...           0.858649
# 2   {'criterion': 'squared_error', 'max_features':...           0.860369
# 3   {'criterion': 'squared_error', 'max_features':...           0.857951
# 4   {'criterion': 'squared_error', 'max_features':...           0.840613
# 5   {'criterion': 'squared_error', 'max_features':...           0.847482
# 6   {'criterion': 'poisson', 'max_features': 'sqrt...           0.856021
# 7   {'criterion': 'poisson', 'max_features': 'sqrt...           0.857895
# 8   {'criterion': 'poisson', 'max_features': 'log2...           0.852021
# 9   {'criterion': 'poisson', 'max_features': 'log2...           0.858002
# 10  {'criterion': 'poisson', 'max_features': 1.0, ...           0.844608
# 11  {'criterion': 'poisson', 'max_features': 1.0, ...           0.846058
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.857562
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.855867
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.860418
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.859302
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.848171
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.849264
# 18  {'criterion': 'absolute_error', 'max_features'...           0.851199
# 19  {'criterion': 'absolute_error', 'max_features'...           0.856727
# 20  {'criterion': 'absolute_error', 'max_features'...           0.850058
# 21  {'criterion': 'absolute_error', 'max_features'...           0.858441
# 22  {'criterion': 'absolute_error', 'max_features'...           0.837872
# 23  {'criterion': 'absolute_error', 'max_features'...           0.842758
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.781143           0.861074           0.825907
# 1            0.780276           0.856852           0.828451
# 2            0.776033           0.857146           0.825772
# 3            0.778473           0.860895           0.829921
# 4            0.773626           0.857924           0.820514
# 5            0.774887           0.856785           0.820402
# 6            0.777060           0.855980           0.827943
# 7            0.779495           0.865376           0.828644
# 8            0.781009           0.855673           0.821552
# 9            0.778159           0.862970           0.826816
# 10           0.769091           0.850419           0.810472
# 11           0.770870           0.863433           0.820433
# 12           0.781680           0.857865           0.830069
# 13           0.778632           0.858769           0.828014
# 14           0.772966           0.860756           0.831270
# 15           0.774730           0.859094           0.826635
# 16           0.774217           0.852257           0.814692
# 17           0.773666           0.854753           0.818159
# 18           0.783468           0.845385           0.824027
# 19           0.779947           0.860317           0.826767
# 20           0.780674           0.849562           0.828104
# 21           0.781421           0.856233           0.828774
# 22           0.774822           0.846641           0.823116
# 23           0.765762           0.850667           0.824456
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.831464         0.832137        0.029379               10
# 1            0.836326         0.832111        0.028405               11
# 2            0.840809         0.832026        0.030613               12
# 3            0.840973         0.833643        0.029816                3
# 4            0.836785         0.825892        0.028713               20
# 5            0.836198         0.827151        0.028811               18
# 6            0.844494         0.832299        0.029471                8
# 7            0.841863         0.834655        0.030380                1
# 8            0.842919         0.830635        0.027497               14
# 9            0.836842         0.832558        0.030275                7
# 10           0.840408         0.823000        0.030282               23
# 11           0.838913         0.827941        0.031691               17
# 12           0.841002         0.833635        0.028021                4
# 13           0.840148         0.832286        0.029039                9
# 14           0.839644         0.833011        0.032166                6
# 15           0.839633         0.831879        0.031133               13
# 16           0.833881         0.824644        0.028437               21
# 17           0.833910         0.825950        0.029089               19
# 18           0.842894         0.829395        0.024704               15
# 19           0.846252         0.834002        0.029439                2
# 20           0.837044         0.829089        0.025562               16
# 21           0.842029         0.833379        0.028093                5
# 22           0.831182         0.822727        0.025170               24
# 23           0.835679         0.823865        0.030302               22

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children = float(input("Children:"))
sex_male = int(input("Sex male 0 or 1:"))
smoker_yes = int(input("Smoker yes 0 or 1:"))
# Out:
# Age:25
# BMI:30
# Children:2
# Sex male 0 or 1:1
# Smoker yes 0 or 1:0

# %%
future_prediction = grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(future_prediction))
# Out:
# Future_Prediction=[7982.9565045]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
