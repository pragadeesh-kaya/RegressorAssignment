# %%
import pandas as pd

dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {'criterion':['squared_error','poisson','friedman_mse','absolute_error'],'splitter':['best','random'],'max_features':['sqrt','log2',None]}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'poisson',
#                                        'friedman_mse', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
table = pd.DataFrame.from_dict(re)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}:

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011645      0.004737         0.009295        0.010647
# 1        0.008810      0.000701         0.001452        0.001746
# 2        0.012791      0.002651         0.000705        0.001410
# 3        0.009566      0.005098         0.002151        0.004301
# 4        0.012107      0.005983         0.008940        0.006657
# 5        0.009654      0.003428         0.004502        0.003627
# 6        0.011662      0.004481         0.004843        0.004014
# 7        0.006980      0.002507         0.003216        0.003080
# 8        0.010685      0.002280         0.003688        0.004037
# 9        0.007716      0.002767         0.003193        0.002397
# 10       0.016196      0.003403         0.002000        0.003093
# 11       0.009412      0.001225         0.001441        0.002882
# 12       0.014081      0.010608         0.004918        0.005280
# 13       0.007189      0.002719         0.003871        0.003570
# 14       0.013125      0.005072         0.003195        0.003913
# 15       0.008341      0.004454         0.003110        0.003616
# 16       0.010992      0.002535         0.012271        0.011983
# 17       0.008341      0.002860         0.005030        0.004228
# 18       0.043490      0.013098         0.008893        0.008271
# 19       0.022448      0.002451         0.003808        0.003926
# 20       0.040532      0.012834         0.007816        0.007997
# 21       0.022798      0.003405         0.002404        0.002937
# 22       0.063696      0.013511         0.004796        0.003916
# 23       0.044963      0.007599         0.001809        0.003617
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6          poisson               sqrt           best
# 7          poisson               sqrt         random
# 8          poisson               log2           best
# 9          poisson               log2         random
# 10         poisson               None           best
# 11         poisson               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18  absolute_error               sqrt           best
# 19  absolute_error               sqrt         random
# 20  absolute_error               log2           best
# 21  absolute_error               log2         random
# 22  absolute_error               None           best
# 23  absolute_error               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.754179
# 1   {'criterion': 'squared_error', 'max_features':...           0.614283
# 2   {'criterion': 'squared_error', 'max_features':...           0.701309
# 3   {'criterion': 'squared_error', 'max_features':...           0.688564
# 4   {'criterion': 'squared_error', 'max_features':...           0.731288
# 5   {'criterion': 'squared_error', 'max_features':...           0.738720
# 6   {'criterion': 'poisson', 'max_features': 'sqrt...           0.745075
# 7   {'criterion': 'poisson', 'max_features': 'sqrt...           0.663819
# 8   {'criterion': 'poisson', 'max_features': 'log2...           0.731133
# 9   {'criterion': 'poisson', 'max_features': 'log2...           0.662828
# 10  {'criterion': 'poisson', 'max_features': None,...           0.748909
# 11  {'criterion': 'poisson', 'max_features': None,...           0.688812
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.688655
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.745717
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.710766
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.619945
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.719221
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.645003
# 18  {'criterion': 'absolute_error', 'max_features'...           0.745845
# 19  {'criterion': 'absolute_error', 'max_features'...           0.629980
# 20  {'criterion': 'absolute_error', 'max_features'...           0.708947
# 21  {'criterion': 'absolute_error', 'max_features'...           0.697452
# 22  {'criterion': 'absolute_error', 'max_features'...           0.730314
# 23  {'criterion': 'absolute_error', 'max_features'...           0.660935
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.585276           0.686499           0.652592
# 1            0.601866           0.648981           0.737528
# 2            0.709021           0.622977           0.613854
# 3            0.615283           0.679625           0.612834
# 4            0.614453           0.735645           0.727585
# 5            0.597732           0.687975           0.743732
# 6            0.346817           0.711798           0.632792
# 7            0.621230           0.721018           0.687527
# 8            0.583513           0.736019           0.678277
# 9            0.552758           0.702614           0.689441
# 10           0.658887           0.724160           0.712889
# 11           0.571880           0.689353           0.721607
# 12           0.475791           0.746631           0.715178
# 13           0.632147           0.663561           0.648067
# 14           0.628176           0.683018           0.575561
# 15           0.530440           0.676035           0.696544
# 16           0.653266           0.729350           0.712230
# 17           0.634495           0.795260           0.705100
# 18           0.552646           0.709459           0.617111
# 19           0.566539           0.641168           0.545675
# 20           0.543954           0.732148           0.746081
# 21           0.620315           0.567736           0.626477
# 22           0.647137           0.700503           0.705553
# 23           0.630328           0.778338           0.737934
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.616688         0.659047        0.058450               15
# 1            0.629258         0.646383        0.048207               19
# 2            0.689589         0.667350        0.040534               13
# 3            0.605247         0.640311        0.036013               20
# 4            0.683556         0.698505        0.046017                6
# 5            0.727925         0.699217        0.054391                5
# 6            0.719348         0.631166        0.147044               22
# 7            0.717677         0.682254        0.037011                9
# 8            0.708685         0.687526        0.055866                8
# 9            0.639920         0.649512        0.053000               18
# 10           0.693294         0.707628        0.030286                2
# 11           0.727708         0.679872        0.056324               10
# 12           0.684143         0.662080        0.095776               14
# 13           0.596443         0.657187        0.049555               16
# 14           0.743226         0.668149        0.059740               12
# 15           0.630915         0.630776        0.057547               23
# 16           0.670043         0.696822        0.029704                7
# 17           0.742939         0.704559        0.060259                3
# 18           0.753693         0.675751        0.078381               11
# 19           0.649106         0.606494        0.042107               24
# 20           0.524070         0.651040        0.096492               17
# 21           0.673685         0.637133        0.045137               21
# 22           0.730783         0.702858        0.030500                4
# 23           0.732779         0.708063        0.054232                1

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children = float(input("Children:"))
sex_male = int(input("Sex male 0 or 1:"))
smoker_yes = int(input("Smoker yes 0 or 1:"))
# Out:
# Age:25
# BMI:30
# Children:2
# Sex male 0 or 1:1
# Smoker yes 0 or 1:0

# %%
future_prediction = grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(future_prediction))
# Out:
# Future_Prediction=[4189.1131]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
